# %% [markdown]
# # Scrapping Data

# %%
# %pip install google-play-scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import app, reviews
import pandas as pd
import os

# %% [markdown]
# #### Scraping ulasana aplikasi Brimo
#
# scraping di Play Store yakni aplikasi Brimo
#
# [Brimo](https://play.google.com/store/apps/details?id=id.co.bri.brimo)

# %%
# Menentukan ID aplikasi Brimo
app_id = 'id.co.bri.brimo'

# Mengambil ulasan
reviews_data, _ = reviews(
    app_id,
    lang='id',
    country='id',
    count=10000
)

# Konversi ke DataFrame
reviews_df = pd.DataFrame(reviews_data)
reviews_df
# Out:
#                                   reviewId                userName  \
# 0     1202ed42-ac00-40ce-96de-7e0999717840         Pengguna Google
# 1     25c7c598-e5d5-4afa-a5fa-82b40399624e         Pengguna Google
# 2     d57324e3-e261-4b6c-bee2-cb3b8ecc3388         Pengguna Google
# 3     8b85c65d-5570-4c8e-a9b4-96a6df5083d9         Pengguna Google
# 4     dc41ea0a-ba3c-4e1b-a26f-5c0ff30ebb2a         Pengguna Google
# ...                                    ...                     ...
# 9995  6eb18fa0-7478-4c8a-9b2a-1b5bae1990ec  Agustin Claristha Yona
# 9996  956a5546-7911-4dcb-a29f-bb4d58f4cd6f            Fitria Ilato
# 9997  c3d34632-3576-4d23-9da3-580541e1cff8           Ahyani Ahyani
# 9998  1399ff98-3753-4b21-abeb-1929e7d20b0c             Hari Chanel
# 9999  c893051b-f970-4978-b9db-2d6eca9983f2           Angki Irpanul
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
# save to csv
reviews_df.to_csv('brimo_reviews.csv', index=False)
